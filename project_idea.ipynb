# %% [markdown]
# ##### You have a restaurant.
# ##### You are having a lot of google reviews on it.
# ##### You want to analyze those reviews
# ##### Analyze button - make a call() to "Backend".
# ##### In the backend it will use "Gemini API" to perform the "Sentiment Analysis"
